# %%
#Datatypes
#String
name = "Satinder"
print(type(name))
# Out:
# <class 'str'>

# %%
name='Satinder'
print(type(name))
# Out:
# <class 'str'>

# %%
name="""Satinder
Name
jksdghf
hdgjkhdfs"""
print(name)
print(type(name))
# Out:
# Satinder
# Name
# jksdghf
# hdgjkhdfs
# <class 'str'>

# %%
#methods
#1 lower()
a= "This is Python"
print(a.lower())
# Out:
# this is python  f g jh

# %%
#2 upper()
a= "This is Python"
print(a.upper())
# Out:
# THIS IS PYTHON

# %%
#3 replace
a ="This is Python"
print(a.replace("Python", "AI"))
# Out:
# This is AI

# %%
#4 split 
a ="This is Python"
print(a.split())
# Out:
# ['This', 'is', 'Python']
# <class 'str'>

# %%
#5 join
a ="This is Python"
print(":".join(a))
# Out:
# T:h:i:s: :i:s: :P:y:t:h:o:n

# %%
a=['This', 'is', 'Python']
print(":".join(a))
# Out:
# This:is:Python

# %%
#Accessing characters using indexing 
a= "Satinder"
print(a[0])
print(a[-1])
# Out:
# S
# r

# %%
#6 find()
text="Learn Python"
print(text.find("m"))
# Out:
# -1

# %%
# 7 strip() : Removes leading and trailing whitespace from a string.
text= "                   Learn Python"
print(text.strip())
# Out:
# Learn Python

# %%
#8 startswith() : Checks wheather a string starts with the specified prefix.
text="Python Learn"
print(text.startswith("L"))
# Out:
# False

# %%
#slicing
#string = s[start: end: step]
a= "abcdefghij"
s= a[2:]
print(s)
# Out:
# cdefghij

# %%
a= "abcdefghij"
s= a[2:5]
print(s)
# Out:
# cde

# %%
a= "abcdefghij"
s= a[:5]
print(s)
# Out:
# abcde

# %%
a= "abcdefghij"
s=a[0:9:3]
print(s)
# Out:
# adg

# %%
# capitalize
text="python program"
print(text.capitalize())
# Out:
# Python program

# %%
#List
a= [1,2,3 ,40 , 80.5, "Satinder"]
print(a)
print(type(a))
# Out:
# [1, 2, 3, 40, 80.5, 'Satinder']
# <class 'list'>

# %%
li= ["name", 25, 67]
print(li)
# Out:
# ['name', 25, 67]

# %%
a= list((1, 3, 4 ,"Satinder"))
print(a)
# Out:
# [1, 3, 4, 'Satinder']

# %%
#accessing the element
new = [25, 55, "Name", 70.6]
print(new[1])
print(new[-1])
# Out:
# 55
# 70.6

# %%
#list
a = [23, 45, "name", 45.50,]
print(a)
print(type(a))
# Out:
# [23, 45, 'name', 45.5]
# <class 'list'>

# %%
a= list((1,2,3,"name"))
print(type(a))
# Out:
# <class 'list'>

# %%
#creating list with repeated elements
a= [2]*10
print(a)
# Out:
# [2, 2, 2, 2, 2, 2, 2, 2, 2, 2]

# %%
#Accessing elements
a= [10, 20, 30, 40]
print(a[1])
# Out:
# 20

# %%
#Adding Elements
#1 append(): Adds an element at the end ogf the list
a= [1,2]
print(a)
a.append(3)
print(a)
# Out:
# [1, 2]
# [1, 2, 3]

# %%
#2: insert(): Adds an element at a specific position.
a= [10, 20, 30]
a.insert(1, 50)
print(a)
# Out:
# [10, 50, 20, 30]

# %%
#3 : extend(): Adds multiple elements to the end of the list.
a= [10, 20, 30]
a.extend([40,50,60])
print(a)
# Out:
# [10, 20, 30, 40, 50, 60]

# %%
#updating element
a= [10, 20, 30]
a[1]=120
print(a)
# Out:
# [10, 120, 30]

# %%
#Removing elements
# remove()
a= [10, 20, 30]
a.remove(20)
print(a)
# Out:
# [10, 30]

# %%
#pop(): Removes the element at a specific index or the last element if no index is specified.
a= [1,2,3]
a.pop()
print(a)
# Out:
# [1, 2]

# %%
#3: del statement: Deletes an element at a specified index.
a=[1,2,3]
del a[1]
print(a)
# Out:
# [1, 3]

# %%
#clear()
a= [1,2,3]
a.clear()
print(a)
# Out:
# []

# %%
#count()
a= [1,2,3,2,2,2]
c= a.count(2)
print(c)
# Out:
# 4

# %%
#sort()
a= [2,1,5,9,3]
a.sort(reverse= True)
print(a)
# Out:
# [9, 5, 3, 2, 1]

# %%
#Datatype:   True / False  Boolean datatypes

# %%
#reverse()
a= [2,1,5,9,3]
a.reverse()
print(a)
# Out:
# [1, 2, 3, 5, 9]

# %%
#copy()
num= [1,2,3]
num.copy()
print(num)
# Out:
# [1, 2, 3]

# %%
#index()

# %%
a=[1,2,30,5]
x= a.index(30)
print(x)
# Out:
# 2

# %%
#tuple
x= (20, 45, 60.5, "satinder", [1,2,3])
print(x)
print(type(x))
# Out:
# (20, 45, 60.5, 'satinder', [1, 2, 3])
# <class 'tuple'>

# %%
#Accessing elements
x= (1,2,3,"name")
print(x[1])
# Out:
# 2

# %%
#len(): length
x= (1,2,3,"name")
print(len(x))
# Out:
# 4

# %%
#Tuple methods
#1: count()
n = (10,20,30,40,50,50)
print(n.count(50))
# Out:
# 2

# %%
#2: index()
n = (10,20,30,40,50,50)
print(n.index(30))
# Out:
# 2

# %%
#slicing
n = (10,20,30,40,50,50)
print(n[1:4])
# Out:
# (20, 30, 40)

# %%
n = (10,20,30,40,50,50)
print(n[1:4])
# Out:
# (10, 20, 30, 40)

# %%
n = (10,20,30,40,50,50)
print(n[4:])
# Out:
# (50, 50)
